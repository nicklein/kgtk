# %% [markdown]
# # Evaluation of Embeddings on a Word-Similarity-Ranking Application
#
# The wordsim353 data we are currently using can be downloaded from here: https://drive.google.com/file/d/1RXJ1fxzk82srGqQQWI8xFavWLBv5T8a6/view?usp=sharing

# %%
import os
import pandas as pd
import random
import numpy as np
from tabulate import tabulate
from gensim.models import KeyedVectors
from tqdm import tqdm
from scipy import stats

# %% [markdown]
# ## Params
# *wordsim_file*: path to tsv file that contains wordsim data
# *embedding_files*: dictionary of {(str) name : (str) file path of .kv embedding file}

# %%
wordsim_file = "./data/wordsim353/wordsim353crowd_results_v2_similarity.tsv"
# wordsim_file = "./data/similarity/ISI Examples for similarity algorithms - qnode_similarity_scores.csv"

embedding_files = {"H_3x6" : "./output/wikidata-20210215-dwd/H_walks_analysis/h_embeddings_3x6,min_count=8.kv",
                   "H_5x8" : "./output/wikidata-20210215-dwd/H_walks_analysis/h_embeddings_5x8,min_count=21.kv",
                   "A" : "./output/wikidata-20210215-dwd/A_walks_analysis/a_embeddings_10x10,min_count=0.kv",
                   "S" : "./output/wikidata-20210215-dwd/S_walks_analysis/s_embeddings_5x10,min_count=0.kv"
                  }

# %% [markdown]
# param setup work

# %%
# ensure paths are absolute
wordsim_file = os.path.abspath(wordsim_file)

for name, file_path in embedding_files.items():
    embedding_files[name] = os.path.abspath(file_path)

# Set up output directories if not created yet
output_dir = os.path.abspath("./output/embeddings_wordsim")
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# %% [markdown]
# ## Loading embeddings and wordsim data

# %%
embedding_models = {}
for name, file_path in embedding_files.items():
    print("now loading {} embeddings".format(name))
    embedding_models[name] = KeyedVectors.load(file_path)
# Out:
# now loading H_3x6 embeddings
# now loading H_5x8 embeddings
# now loading A embeddings
# now loading S embeddings

# %%
df = pd.read_csv(wordsim_file, sep='\t')
# df = pd.read_csv(wordsim_file)
display(df.head())
# Out:
#          Word 1 word1_kg_id      word1_kg_label  \
# 0     admission     Q847337          confession
# 1       alcohol        Q154  alcoholic beverage
# 2      aluminum        Q663           aluminium
# 3  announcement     Q567303        announcement
# 4  announcement     Q567303        announcement
#
#                                 word1_kg_description     Word 2 word2_kg_id  \
# 0  statement made by a person or a group of perso...     ticket     Q551800
# 1       drink containing alcohols, typically ethanol  chemistry       Q2329
# 2  metallic chemical element of silvery appearanc...      metal      Q11426
# 3  printed, spoken, or published statement or not...     effort   Q14536140
# 4  printed, spoken, or published statement or not...       news      Q38926
#
#   word2_kg_label                               word2_kg_description  \
# 0         ticket  paper or cardboard document showing payment fo...
# 1      chemistry  branch of physical science concerned with the ...
# 2          metal  element, compound or alloy that is a good cond...
# 3       exertion    use of physical or perceived energy by a person
# 4           news  communication of selected information on curre...
#
#    Human (Mean)   complex    transe      text     class
# 0        5.5360  0.361115  0.446632  0.485653       NaN
# 1        4.1250  0.302163  0.274388  0.479313  0.005851
# 2        6.6250  0.694462  0.429289  0.626784  0.393657
# 3        2.0625  0.324825  0.379077  0.618644  0.208812
# 4        7.1875  0.361214  0.360383  0.863846  0.888621

# %% [markdown]
# ## Preliminary analysis
# Let's see how many of these entities are represented in our embeddings

# %%
headers = ["", "# rows with 2 words", "# words"] + ["in {}".format(name) for name in embedding_models]
rows=[]

word1_non_empty = np.array([word != "" for word in df.word1_kg_id])
word2_non_empty = np.array([word != "" for word in df.word2_kg_id])
row = ["Total",
       sum(word1_non_empty & word2_non_empty),
       sum(word1_non_empty) + sum(word2_non_empty)
      ]
rows.append(row)

for name, model in embedding_models.items():
    word1_has_embedding = np.array([word in model for word in df.word1_kg_id])
    word2_has_embedding = np.array([word in model for word in df.word2_kg_id])
    row = [name,
           sum(word1_has_embedding & word2_has_embedding),
           sum(word1_has_embedding) + sum(word2_has_embedding)
          ]
    rows.append(row)
    
print(tabulate(rows, headers=headers))

for name, model in embedding_models.items():
    print("\nEntities missed by {}:".format(name))
    for i in range(len(df)):
        if df.word1_kg_id[i] not in model:
            print("{} - {} ({})".format(df.word1_kg_id[i], df['Word 1'][i], df.word1_kg_label[i]))
        if df.word2_kg_id[i] not in model:
            print("{} - {} ({})".format(df.word2_kg_id[i], df['Word 2'][i], df.word2_kg_label[i]))
# Out:
#          # rows with 2 words    # words
# -----  ---------------------  ---------
# Total                    349        698
# H_3x6                    344        693
# H_5x8                    342        691
# A                         19         87
# S                        239        572
#
# Entities missed by H_3x6:
# Q181201 - dividend (dividend)
# Q3149193 - impartiality (impartiality)
# Q2357965 - quarrel (Quarrel)
# Q10956426 - match (match)
# Q11812495 - viewer (viewer)
#
# Entities missed by H_5x8:
# Q181201 - dividend (dividend)
# Q32341 - fuck (fuck)
# Q3149193 - impartiality (impartiality)
# Q2357965 - quarrel (Quarrel)
# Q1746570 - hardware (Hardware)
# Q10956426 - match (match)
# Q11812495 - viewer (viewer)
#
# Entities missed by A:
# Q847337 - admission (confession)
# Q551800 - ticket (ticket)
# Q154 - alcohol (alcoholic beverage)
# Q2329 - chemistry (chemistry)
# Q11426 - metal (metal)
# Q567303 - announcement (announcement)
# Q14536140 - effort (exertion)
# Q567303 - announcement (announcement)
# Q38926 - news (news)
# Q567303 - announcement (announcement)
# Q739302 - production (production)
# Q567303 - announcement (announcement)
# Q1759104 - warning (warning)
# Q454 - peace (peace)
# Q13648784 - terror (terror)
# Q12271 - architecture (architecture)
# Q2006324 - arrangement (agreement)
# Q64576680 - accommodation (accommodation)
# Q210999 - asylum (psychiatric hospital)
# Q210999 - madhouse (psychiatric hospital)
# Q3230 - atmosphere (atmosphere of Earth)
# Q107425 - landscape (landscape)
# Q12897867 - attempt (attempt)
# Q454 - peace (peace)
# Q998 - baby (baby)
# Q22687 - bank (bank)
# Q1368 - money (money)
# Q1539532 - season (sports season of a sports club)
# Q42177 - bed (bed)
# Q1723368 - closet (closet)
# Q367293 - benchmark (convention)
# Q25472932 - index (index)
# Q5113 - bird (bird)
# Q2216236 - cock (rooster)
# Q5113 - bird (bird)
# Q25365 - crane (Gruidae)
# Q29182 - bishop (bishop)
# Q133485 - rabbi (rabbi)
# Q865588 - board (committee)
# Q1630279 - recommendation (guideline)
# Q571 - book (book)
# Q7075 - library (library)
# Q571 - book (book)
# Q11472 - paper (paper)
# Q32112 - boxing (boxing)
# Q58092637 - round (round)
# Q3010 - boy (boy)
# Q3010 - lad (boy)
# Q7802 - bread (bread)
# Q10861465 - brother (brother)
# Q733786 - monk (monk)
# Q622821 - calculation (calculation)
# Q12525525 - computation (computation)
# Q150784 - canyon (canyon)
# Q107425 - landscape (landscape)
# Q1420 - car (motor car)
# Q1420 - automobile (motor car)
# Q1420 - car (motor car)
# Q15921555 - flight (flight)
# Q7868 - cell (cell)
# Q17517 - phone (mobile phone)
# Q39614 - cemetery (cemetery)
# Q3241565 - woodland (woodland)
# Q6266 - nation (nation)
# Q1079023 - championship (championship)
# Q500834 - tournament (tournament)
# Q3851114 - chance (opportunity)
# Q1530061 - credibility (credibility)
# Q1150070 - change (change)
# Q622645 - attitude (attitude)
# Q188191 - chord (chord)
# Q487 - smile (smile)
# Q106106 - closet (wardrobe)
# Q11460 - clothes (clothing)
# Q93352 - coast (coast)
# Q4421 - forest (forest)
# Q93352 - coast (coast)
# Q54050 - hill (hill)
# Q93352 - coast (coast)
# Q468756 - shore (shore)
# Q6881511 - company (enterprise)
# Q1196314 - stock (stock)
# Q841654 - competition (competition)
# Q160151 - price (price)
# Q68 - computer (computer)
# Q68 - computer (computer)
# Q250 - keyboard (computer keyboard)
# Q68 - computer (computer)
# Q483242 - laboratory (laboratory)
# Q68 - computer (computer)
# Q38926 - news (news)
# Q68 - computer (computer)
# Q7397 - software (software)
# Q182832 - concert (concert)
# Q214970 - virtuoso (virtuoso)
# Q22855 - consumer (consumer)
# Q4116378 - confidence (confidence)
# Q22855 - consumer (consumer)
# Q11379 - energy (energy)
# Q6256 - country (country)
# Q2472587 - citizen (people)
# Q178692 - crane (crane)
# Q39546 - implement (tool)
# Q305253 - credit (credit)
# Q42965339 - card (card)
# Q305253 - credit (credit)
# Q11028 - information (information)
# Q2735883 - cucumber (cucumber)
# Q10998 - potato (potato)
# Q81727 - cup (cup)
# Q191067 - article (article)
# Q81727 - cup (cup)
# Q8205328 - artifact (artificial physical object)
# Q81727 - cup (cup)
# Q8486 - coffee (coffee)
# Q81727 - cup (cup)
# Q40050 - drink (drink)
# Q81727 - cup (cup)
# Q35120 - entity (entity)
# Q81727 - cup (cup)
# Q2095 - food (food)
# Q81727 - cup (cup)
# Q11435 - liquid (liquid)
# Q81727 - cup (cup)
# Q488383 - object (object)
# Q81727 - cup (cup)
# Q27166344 - substance (substance)
# Q81727 - cup (cup)
# Q851782 - tableware (tableware)
# Q8142 - currency (currency)
# Q37654 - market (market)
# Q11326182 - dawn (dawn)
# Q1313 - summer (summer)
# Q4 - death (death)
# Q1862087 - inmate (prisoner)
# Q4 - death (death)
# Q1366302 - row (row)
# Q6149036 - decoration (decoration)
# Q194112 - valor (value)
# Q21075709 - delay (delay)
# Q38926 - news (news)
# Q21075709 - delay (delay)
# Q8461 - racism (racism)
# Q1308677 - deployment (deployment)
# Q21171241 - departure (departure)
# Q1308677 - deployment (deployment)
# Q1760704 - withdrawal (withdrawal)
# Q26132748 - development (development)
# Q26256810 - issue (matter)
# Q2151613 - direction (direction)
# Q202805 - combination (combination)
# Q12131 - disability (disability)
# Q4 - death (death)
# Q3839081 - disaster (disaster)
# Q1496967 - area (territorial entity)
# Q12772819 - discovery (discovery)
# Q107 - space (space)
# Q55091473 - dividend (dividend)
# Q622821 - calculation (calculation)
# Q181201 - dividend (dividend)
# Q1148747 - payment (payment)
# Q39631 - doctor (physician)
# Q1274115 - liability (responsibility)
# Q39631 - doctor (physician)
# Q186360 - nurse (nurse)
# Q39631 - doctor (physician)
# Q703534 - personnel (employee)
# Q1368 - buck (money)
# Q13135567 - loss (economic loss)
# Q26911 - profit (economic profit)
# Q40050 - drink (drink)
# Q1420 - car (motor car)
# Q40050 - drink (drink)
# Q7362 - ear (ear)
# Q40050 - drink (drink)
# Q213449 - eat (eating)
# Q40050 - drink (drink)
# Q40050 - drink (drink)
# Q9635 - mouth (mouth)
# Q12140 - drug (medication)
# Q600571 - abuse (abuse)
# Q11379 - energy (energy)
# Q381072 - crisis (crisis)
# Q11379 - energy (energy)
# Q483242 - laboratory (laboratory)
# Q11379 - energy (energy)
# Q80687 - secretary (secretary)
# Q2249676 - environment (environment)
# Q7150 - ecology (ecology)
# Q16798631 - equipment (equipment)
# Q13235160 - maker (producer)
# Q11985689 - exhibit (exhibit)
# Q212469 - memorabilia (souvenir)
# Q1355387 - experience (experience)
# Q638 - music (music)
# Q8436 - family (family)
# Q309100 - planning (planning)
# Q178022 - fingerprint (fingerprint)
# Q21004260 - investigation (inquiry)
# Q964401 - fertility (fertility)
# Q17147 - egg (egg)
# Q650711 - fighting (combat)
# Q11499267 - defeating (defeat)
# Q63540903 - focus (focal ppint)
# Q3 - life (life)
# Q2095 - food (food)
# Q3314483 - fruit (fruit)
# Q2095 - food (food)
# Q19833559 - preparation (preparation)
# Q2095 - food (food)
# Q2216236 - rooster (rooster)
# Q4421 - forest (forest)
# Q39614 - graveyard (cemetery)
# Q32341 - fuck (fuck)
# Q5873 - sex (sexual intercourse)
# Q1709184 - furnace (heating furnace)
# Q203789 - stove (stove)
# Q11410 - game (game)
# Q11499267 - defeat (defeat)
# Q11410 - game (game)
# Q58092637 - round (round)
# Q11410 - game (game)
# Q20937557 - series (series)
# Q11410 - game (game)
# Q12973014 - team (sports team)
# Q11410 - game (game)
# Q50000 - victory (victory)
# Q83437 - gem (gemstone)
# Q83437 - jewel (gemstone)
# Q48277 - gender (gender)
# Q773009 - equality (equality)
# Q15855449 - magician (magician)
# Q11426 - metal (metal)
# Q7188 - government (government)
# Q381072 - crisis (crisis)
# Q48352 - governor (head of state)
# Q178651 - interview (interview)
# Q48352 - governor (head of state)
# Q4164871 - office (position)
# Q951964 - grocery (food product)
# Q1368 - money (money)
# Q16917 - hospital (hospital)
# Q121359 - infrastructure (infrastructure)
# Q27686 - hotel (hotel)
# Q57237926 - reservation (reservation)
# Q478798 - image (image)
# Q28840755 - surface (surface)
# Q3149193 - impartiality (impartiality)
# Q616314 - interest (interest)
# Q21004260 - investigation (inquiry)
# Q14536140 - effort (exertion)
# Q557880 - investor (investor)
# Q570938 - earning (net income)
# Q1420 - car (motor car)
# Q846570 - American (Americans)
# Q49850 - journal (journal)
# Q744778 - association (association)
# Q61509 - journey (travel)
# Q1420 - car (motor car)
# Q61509 - journey (travel)
# Q17990955 - voyage (sea voyage)
# Q12097 - king (king)
# Q14328596 - cabbage (cabbage)
# Q12097 - king (king)
# Q16511993 - queen (queen)
# Q12097 - king (king)
# Q137 - rook (rook)
# Q3010 - lad (boy)
# Q10861465 - brother (brother)
# Q3010 - lad (boy)
# Q148401 - wizard (fictional magician)
# Q7748 - law (law)
# Q40348 - lawyer (lawyer)
# Q40348 - lawyer (lawyer)
# Q176763 - evidence (evidence)
# Q1274115 - liability (responsibility)
# Q43183 - insurance (insurance)
# Q3 - life (life)
# Q4 - death (death)
# Q3 - life (life)
# Q379833 - lesson (lesson)
# Q3 - life (life)
# Q1969448 - term (term)
# Q1228250 - line (line)
# Q43183 - insurance (insurance)
# Q798505 - listing (listing)
# Q21146257 - category (type)
# Q798505 - listing (listing)
# Q19267375 - proximity (proximity)
# Q61864890 - lobster (lobster)
# Q2095 - food (food)
# Q61864890 - lobster (lobster)
# Q282 - wine (wine)
# Q316 - love (love)
# Q5873 - sex (sexual intercourse)
# Q316 - lover (love)
# Q2357965 - quarrel (Quarrel)
# Q10953913 - luxury (luxury)
# Q1420 - car (motor car)
# Q15855449 - magician (magician)
# Q148401 - wizard (fictional magician)
# Q8441 - man (man)
# Q48352 - governor (head of state)
# Q8441 - man (man)
# Q467 - woman (woman)
# Q56199072 - sprint (sprint)
# Q901 - scientist (scientist)
# Q340169 - media (communication medium)
# Q4165229 - gain (gain)
# Q340169 - media (communication medium)
# Q159391 - radio (radio receiver)
# Q340169 - media (communication medium)
# Q105427573 - trading (trading)
# Q168182 - midday (noon)
# Q168182 - noon (noon)
# Q83307 - minister (minister)
# Q7278 - party (political party)
# Q192350 - ministry (ministry)
# Q11042 - culture (culture)
# Q769696 - minority (ethnic minority)
# Q454 - peace (peace)
# Q1368 - money (money)
# Q22687 - bank (bank)
# Q1368 - money (money)
# Q693464 - cash (cash)
# Q1368 - money (money)
# Q693464 - cash (cash)
# Q1368 - money (money)
# Q693464 - cash (cash)
# Q1368 - money (money)
# Q693464 - cash (cash)
# Q1368 - money (money)
# Q8142 - currency (currency)
# Q1368 - money (money)
# Q5260774 - deposit (deposit)
# Q1368 - money (money)
# Q1368 - money (money)
# Q151900 - laundering (money laundering)
# Q1368 - money (money)
# Q28972820 - operation (operation)
# Q1368 - money (money)
# Q1400881 - possession (property)
# Q1368 - money (money)
# Q1400881 - possession (property)
# Q1368 - money (money)
# Q1400881 - property (property)
# Q1368 - money (money)
# Q1400881 - property (property)
# Q1368 - money (money)
# Q200535 - wealth (wealth)
# Q1368 - money (money)
# Q99496317 - withdrawal (withdrawal)
# Q733786 - monk (monk)
# Q217123 - oracle (oracle)
# Q733786 - monk (monk)
# Q12773225 - slave (enslaved person)
# Q27686 - hotel (hotel)
# Q48324 - morality (morality)
# Q16886469 - importance (importance)
# Q48324 - morality (morality)
# Q8445 - marriage (marriage)
# Q11424 - movie (film)
# Q6430706 - critic (critic)
# Q11424 - movie (film)
# Q165112 - popcorn (popcorn)
# Q11424 - movie (film)
# Q1765879 - star (leading actor)
# Q11424 - movie (film)
# Q11635 - theater (theater)
# Q132821 - murder (murder)
# Q3882220 - manslaughter (manslaughter)
# Q33506 - museum (museum)
# Q11635 - theater (theater)
# Q638 - music (music)
# Q170584 - project (project)
# Q7860 - nature (nature)
# Q2249676 - environment (environment)
# Q7860 - nature (nature)
# Q8441 - man (man)
# Q1900326 - network (network)
# Q1746570 - hardware (Hardware)
# Q38926 - news (news)
# Q10870555 - report (report)
# Q168182 - noon (noon)
# Q184754 - string (string)
# Q193181 - observation (observation)
# Q12271 - architecture (architecture)
# Q1196314 - stock (stock)
# Q6256 - country (country)
# Q268592 - industry (industry)
# Q35140 - performance (performance)
# Q454 - peace (peace)
# Q3230 - atmosphere (atmosphere of Earth)
# Q454 - peace (peace)
# Q43183 - insurance (insurance)
# Q454 - peace (peace)
# Q1371819 - plan (plan)
# Q17517 - phone (mobile phone)
# Q16798631 - equipment (equipment)
# Q413 - physics (physics)
# Q2329 - chemistry (chemistry)
# Q413 - physics (physics)
# Q17285 - plane (plane)
# Q1420 - car (motor car)
# Q634 - planet (planet)
# Q11063 - astronomer (astronomer)
# Q634 - planet (planet)
# Q8928 - constellation (constellation)
# Q634 - planet (planet)
# Q318 - galaxy (galaxy)
# Q634 - planet (planet)
# Q634 - planet (planet)
# Q2472587 - people (people)
# Q634 - planet (planet)
# Q107 - space (space)
# Q634 - planet (planet)
# Q523 - star (star)
# Q2625603 - population (population)
# Q18587469 - development (residential community)
# Q21170479 - possibility (possibility)
# Q3031 - girl (girl)
# Q334600 - practice (practice)
# Q178706 - institution (institution)
# Q19269277 - precedent (first)
# Q260460 - antecedent (antecedent)
# Q19269277 - precedent (first)
# Q2200417 - cognition (cognition)
# Q19269277 - precedent (first)
# Q2668072 - collection (collection)
# Q19269277 - precedent (first)
# Q14944328 - example (example)
# Q19269277 - precedent (first)
# Q16887380 - group (group)
# Q19269277 - precedent (first)
# Q11028 - information (information)
# Q665141 - precedent (precedent)
# Q7748 - law (law)
# Q179742 - prejudice (prejudice)
# Q7302601 - recognition (recognition)
# Q1479406 - preservation (preservation)
# Q16502 - world (world)
# Q30461 - president (president)
# Q131647 - medal (medal)
# Q621184 - problem (problem)
# Q1248784 - airport (airport)
# Q621184 - problem (problem)
# Q16511806 - challenge (challenge)
# Q739302 - production (production)
# Q345844 - crew (crew)
# Q739302 - production (production)
# Q12014207 - hike (trekking)
# Q121594 - professor (professor)
# Q2735883 - cucumber (cucumber)
# Q121594 - professor (professor)
# Q39631 - doctor (physician)
# Q26911 - profit (economic profit)
# Q13135567 - loss (economic loss)
# Q1313 - summer (summer)
# Q7860 - nature (nature)
# Q11035 - telephone (telephone)
# Q11024 - communication (communication)
# Q289 - television (television)
# Q11424 - film (film)
# Q289 - television (television)
# Q153362 - racket (tennis racquet)
# Q183366 - territory (territory)
# Q183366 - territory (territory)
# Q484298 - surface (surface)
# Q11635 - theater (theater)
# Q309 - history (history)
# Q729 - animal (animal)
# Q81875 - carnivore (carnivore)
# Q104021 - fauna (fauna)
# Q42602 - feline (Felinae)
# Q7377 - mammal (mammal)
# Q7239 - organism (organism)
# Q43501 - zoo (zoo)
# Q39546 - tool (tool)
# Q39546 - implement (tool)
# Q870 - train (train)
# Q1420 - car (motor car)
# Q61509 - travel (travel)
# Q1914636 - activity (activity)
# Q179661 - treatment (treatment)
# Q85029384 - recovery (recovery)
# Q21146257 - type (type)
# Q21146257 - kind (type)
# Q1851760 - victim (victim)
# Q5070802 - emergency (emergency)
# Q98069877 - video (video)
# Q49848 - archive (document)
# Q11812495 - viewer (viewer)
# Q15709880 - serial (serial)
# Q374 - vodka (vodka)
# Q146470 - brandy (brandy)
# Q374 - vodka (vodka)
# Q24716636 - volunteer (volunteer)
# Q42470 - motto (motto)
# Q198 - war (war)
# Q1080137 - troops (troop)
# Q728 - weapon (weapon)
# Q1503443 - secret (secrecy)
# Q11663 - weather (weather)
# Q748250 - forecast (prediction)
# Q128 - Wednesday (Wednesday)
# Q38926 - news (news)
# Q287 - wood (wood)
# Q4421 - forest (forest)
# Q8171 - word (word)
# Q26161438 - similarity (approximate equality)
#
# Entities missed by S:
# Q14536140 - effort (exertion)
# Q1759104 - warning (warning)
# Q13648784 - terror (terror)
# Q2006324 - arrangement (agreement)
# Q64576680 - accommodation (accommodation)
# Q12897867 - attempt (attempt)
# Q1723368 - closet (closet)
# Q25472932 - index (index)
# Q1630279 - recommendation (guideline)
# Q12525525 - computation (computation)
# Q15921555 - flight (flight)
# Q3241565 - woodland (woodland)
# Q500834 - tournament (tournament)
# Q3851114 - chance (opportunity)
# Q1150070 - change (change)
# Q188191 - chord (chord)
# Q841654 - competition (competition)
# Q160151 - price (price)
# Q4116378 - confidence (confidence)
# Q305253 - credit (credit)
# Q305253 - credit (credit)
# Q81727 - cup (cup)
# Q81727 - cup (cup)
# Q81727 - cup (cup)
# Q81727 - cup (cup)
# Q81727 - cup (cup)
# Q81727 - cup (cup)
# Q81727 - cup (cup)
# Q81727 - cup (cup)
# Q81727 - cup (cup)
# Q27166344 - substance (substance)
# Q81727 - cup (cup)
# Q1366302 - row (row)
# Q21075709 - delay (delay)
# Q21075709 - delay (delay)
# Q1308677 - deployment (deployment)
# Q21171241 - departure (departure)
# Q1308677 - deployment (deployment)
# Q26132748 - development (development)
# Q26256810 - issue (matter)
# Q2151613 - direction (direction)
# Q12772819 - discovery (discovery)
# Q55091473 - dividend (dividend)
# Q181201 - dividend (dividend)
# Q1274115 - liability (responsibility)
# Q13135567 - loss (economic loss)
# Q11985689 - exhibit (exhibit)
# Q1355387 - experience (experience)
# Q11499267 - defeating (defeat)
# Q63540903 - focus (focal ppint)
# Q32341 - fuck (fuck)
# Q11499267 - defeat (defeat)
# Q20937557 - series (series)
# Q773009 - equality (equality)
# Q57237926 - reservation (reservation)
# Q28840755 - surface (surface)
# Q3149193 - impartiality (impartiality)
# Q14536140 - effort (exertion)
# Q570938 - earning (net income)
# Q744778 - association (association)
# Q17990955 - voyage (sea voyage)
# Q14328596 - cabbage (cabbage)
# Q1274115 - liability (responsibility)
# Q1228250 - line (line)
# Q21146257 - category (type)
# Q19267375 - proximity (proximity)
# Q2357965 - quarrel (Quarrel)
# Q4165229 - gain (gain)
# Q105427573 - trading (trading)
# Q168182 - midday (noon)
# Q168182 - noon (noon)
# Q28972820 - operation (operation)
# Q99496317 - withdrawal (withdrawal)
# Q16886469 - importance (importance)
# Q1746570 - hardware (Hardware)
# Q10870555 - report (report)
# Q168182 - noon (noon)
# Q35140 - performance (performance)
# Q17285 - plane (plane)
# Q18587469 - development (residential community)
# Q21170479 - possibility (possibility)
# Q19269277 - precedent (first)
# Q260460 - antecedent (antecedent)
# Q19269277 - precedent (first)
# Q19269277 - precedent (first)
# Q2668072 - collection (collection)
# Q19269277 - precedent (first)
# Q14944328 - example (example)
# Q19269277 - precedent (first)
# Q16887380 - group (group)
# Q19269277 - precedent (first)
# Q7302601 - recognition (recognition)
# Q1479406 - preservation (preservation)
# Q16511806 - challenge (challenge)
# Q12014207 - hike (trekking)
# Q13135567 - loss (economic loss)
# Q1759104 - warning (warning)
# Q1789452 - criterion (criterion)
# Q95566669 - hypertension (hypertension)
# Q2399307 - registration (registration)
# Q10870555 - report (report)
# Q4165229 - gain (gain)
# Q17990955 - voyage (sea voyage)
# Q17525443 - center (middle)
# Q20937557 - series (series)
# Q3241565 - woodland (woodland)
# Q1514190 - recess (school holiday)
# Q2141565 - situation (situation)
# Q20665666 - conclusion (conclusion)
# Q2141565 - situation (situation)
# Q23498130 - isolation (isolation)
# Q1519566 - prominence (fame)
# Q795 - stupid (stupidity)
# Q529711 - start (beginning)
# Q10956426 - match (match)
# Q529711 - start (beginning)
# Q1348006 - block (city block)
# Q1914636 - activity (activity)
# Q85029384 - recovery (recovery)
# Q21146257 - type (type)
# Q21146257 - kind (type)
# Q5070802 - emergency (emergency)
# Q98069877 - video (video)
# Q11812495 - viewer (viewer)
# Q15709880 - serial (serial)
# Q26161438 - similarity (approximate equality)

# %%
headers = ["", "# rows with 2 words", "# words"] + ["in {}".format(name) for name in embedding_models]
rows=[]

word1_non_empty = np.array([word != "" for word in df.g_qnode])
word2_non_empty = np.array([word != "" for word in df.p_qnode])
row = ["Total",
       sum(word1_non_empty & word2_non_empty),
       sum(word1_non_empty) + sum(word2_non_empty)
      ]
rows.append(row)

for name, model in embedding_models.items():
    word1_has_embedding = np.array([word in model for word in df.g_qnode])
    word2_has_embedding = np.array([word in model for word in df.p_qnode])
    row = [name,
           sum(word1_has_embedding & word2_has_embedding),
           sum(word1_has_embedding) + sum(word2_has_embedding)
          ]
    rows.append(row)
    
print(tabulate(rows, headers=headers))

for name, model in embedding_models.items():
    print("\nEntities missed by {}:".format(name))
    for i in range(len(df)):
        if df.g_qnode[i] not in model:
            print("{} - {}".format(df.g_qnode[i], df.q1_label[i]))
        if df.p_qnode[i] not in model:
            print("{} - {}".format(df.p_qnode[i], df.q2_label[i]))
# Out:
#          # rows with 2 words    # words
# -----  ---------------------  ---------
# Total                    118        236
# H_3x6                    118        236
# H_5x8                    118        236
# A                          0          0
# S                         85        199
#
# Entities missed by H_3x6:
#
# Entities missed by H_5x8:
#
# Entities missed by A:
# Q17221 - spokesperson
# Q189290 - military officer
# Q702269 - professional
# Q2285706 - head of government
# Q2285706 - head of government
# Q82955 - politician
# Q107711 - firefighter
# Q189290 - military officer
# Q702269 - professional
# Q48352 - head of state
# Q48352 - head of state
# Q82955 - politician
# Q2285706 - head of government
# Q83307 - minister
# Q48352 - head of state
# Q83307 - minister
# Q1251441 - leader
# Q83307 - minister
# Q9352089 - spy
# Q189290 - military officer
# Q201948 - sniper
# Q1930187 - journalist
# Q1414937 - combatant
# Q1930187 - journalist
# Q82955 - politician
# Q11499147 - political activist
# Q245065 - intergovernmental organization
# Q327333 - government agency
# Q245065 - intergovernmental organization
# Q327333 - government agency
# Q245065 - intergovernmental organization
# Q327333 - government agency
# Q245065 - intergovernmental organization
# Q327333 - government agency
# Q245065 - intergovernmental organization
# Q7278 - political party
# Q17221 - spokesperson
# Q2285706 - head of government
# Q2285706 - head of government
# Q17221 - spokesperson
# Q17221 - spokesperson
# Q48352 - head of state
# Q48352 - head of state
# Q17221 - spokesperson
# Q2285706 - head of government
# Q189290 - military officer
# Q245065 - intergovernmental organization
# Q7188 - government
# Q245065 - intergovernmental organization
# Q7188 - government
# Q245065 - intergovernmental organization
# Q7188 - government
# Q245065 - intergovernmental organization
# Q7188 - government
# Q48352 - head of state
# Q189290 - military officer
# Q702269 - professional
# Q215627 - person
# Q702269 - professional
# Q189290 - military officer
# Q702492 - urban area
# Q22667 - railway
# Q702492 - urban area
# Q22667 - railway
# Q702492 - urban area
# Q22667 - railway
# Q702492 - urban area
# Q22667 - railway
# Q245065 - intergovernmental organization
# Q10553309 - legislative house
# Q245065 - intergovernmental organization
# Q10553309 - legislative house
# Q245065 - intergovernmental organization
# Q10553309 - legislative house
# Q245065 - intergovernmental organization
# Q10553309 - legislative house
# Q702492 - urban area
# Q327333 - government agency
# Q702492 - urban area
# Q327333 - government agency
# Q702492 - urban area
# Q327333 - government agency
# Q702492 - urban area
# Q327333 - government agency
# Q201948 - sniper
# Q83307 - minister
# Q702492 - urban area
# Q7278 - political party
# Q532 - village
# Q22667 - railway
# Q532 - village
# Q22667 - railway
# Q532 - village
# Q22667 - railway
# Q532 - village
# Q22667 - railway
# Q11499147 - political activist
# Q83307 - minister
# Q245065 - intergovernmental organization
# Q16334295 - group of humans
# Q702492 - urban area
# Q16334295 - group of humans
# Q532 - village
# Q327333 - government agency
# Q532 - village
# Q327333 - government agency
# Q532 - village
# Q327333 - government agency
# Q532 - village
# Q327333 - government agency
# Q532 - village
# Q7278 - political party
# Q1414937 - combatant
# Q83307 - minister
# Q702492 - urban area
# Q7188 - government
# Q702492 - urban area
# Q7188 - government
# Q702492 - urban area
# Q7188 - government
# Q702492 - urban area
# Q7188 - government
# Q16334295 - group of humans
# Q7278 - political party
# Q9352089 - spy
# Q215627 - person
# Q702492 - urban area
# Q10553309 - legislative house
# Q702492 - urban area
# Q10553309 - legislative house
# Q702492 - urban area
# Q10553309 - legislative house
# Q702492 - urban area
# Q10553309 - legislative house
# Q532 - village
# Q7188 - government
# Q532 - village
# Q7188 - government
# Q532 - village
# Q7188 - government
# Q532 - village
# Q7188 - government
# Q532 - village
# Q16334295 - group of humans
# Q532 - village
# Q10553309 - legislative house
# Q532 - village
# Q10553309 - legislative house
# Q532 - village
# Q10553309 - legislative house
# Q532 - village
# Q10553309 - legislative house
# Q17221 - spokesperson
# Q215627 - person
# Q107711 - firefighter
# Q215627 - person
# Q245065 - intergovernmental organization
# Q22667 - railway
# Q245065 - intergovernmental organization
# Q22667 - railway
# Q245065 - intergovernmental organization
# Q22667 - railway
# Q245065 - intergovernmental organization
# Q22667 - railway
# Q9352089 - spy
# Q2285706 - head of government
# Q2285706 - head of government
# Q47064 - military personnel
# Q2285706 - head of government
# Q47064 - military personnel
# Q9352089 - spy
# Q48352 - head of state
# Q48352 - head of state
# Q47064 - military personnel
# Q48352 - head of state
# Q47064 - military personnel
# Q107711 - firefighter
# Q2285706 - head of government
# Q1048835 - political territorial entity
# Q22667 - railway
# Q1048835 - political territorial entity
# Q22667 - railway
# Q1048835 - political territorial entity
# Q22667 - railway
# Q1048835 - political territorial entity
# Q22667 - railway
# Q107711 - firefighter
# Q48352 - head of state
# Q82794 - geographic region
# Q174782 - square
# Q215627 - person
# Q2855502 - chief of police
# Q702492 - urban area
# Q12909644 - political ideology
# Q12909644 - political ideology
# Q7278 - political party
# Q532 - village
# Q12909644 - political ideology
# Q12909644 - political ideology
# Q27096235 - artificial geographic entity
# Q16334295 - group of humans
# Q27096235 - artificial geographic entity
# Q215627 - person
# Q82794 - geographic region
# Q1048835 - political territorial entity
# Q16334295 - group of humans
# Q1048835 - political territorial entity
# Q327333 - government agency
# Q1048835 - political territorial entity
# Q327333 - government agency
# Q1048835 - political territorial entity
# Q327333 - government agency
# Q1048835 - political territorial entity
# Q327333 - government agency
# Q1048835 - political territorial entity
# Q7188 - government
# Q1048835 - political territorial entity
# Q7188 - government
# Q1048835 - political territorial entity
# Q7188 - government
# Q1048835 - political territorial entity
# Q7188 - government
# Q1048835 - political territorial entity
# Q10553309 - legislative house
# Q1048835 - political territorial entity
# Q10553309 - legislative house
# Q1048835 - political territorial entity
# Q10553309 - legislative house
# Q1048835 - political territorial entity
# Q10553309 - legislative house
# Q1048835 - political territorial entity
# Q7278 - political party
# Q1048835 - political territorial entity
# Q12909644 - political ideology
# Q245065 - intergovernmental organization
# Q12909644 - political ideology
#
# Entities missed by S:
# Q10553309 - legislative house
# Q10553309 - legislative house
# Q10553309 - legislative house
# Q10553309 - legislative house
# Q10553309 - legislative house
# Q10553309 - legislative house
# Q10553309 - legislative house
# Q10553309 - legislative house
# Q10553309 - legislative house
# Q10553309 - legislative house
# Q10553309 - legislative house
# Q10553309 - legislative house
# Q1048835 - political territorial entity
# Q1048835 - political territorial entity
# Q1048835 - political territorial entity
# Q1048835 - political territorial entity
# Q27096235 - artificial geographic entity
# Q27096235 - artificial geographic entity
# Q1048835 - political territorial entity
# Q1048835 - political territorial entity
# Q1048835 - political territorial entity
# Q1048835 - political territorial entity
# Q1048835 - political territorial entity
# Q1048835 - political territorial entity
# Q1048835 - political territorial entity
# Q1048835 - political territorial entity
# Q1048835 - political territorial entity
# Q1048835 - political territorial entity
# Q10553309 - legislative house
# Q1048835 - political territorial entity
# Q10553309 - legislative house
# Q1048835 - political territorial entity
# Q10553309 - legislative house
# Q1048835 - political territorial entity
# Q10553309 - legislative house
# Q1048835 - political territorial entity
# Q1048835 - political territorial entity

# %% [markdown]
# ## add word similarities according to embeddings

# %%
for name, model in embedding_models.items():
    sims = []
    for i in range(len(df)):
        ent1 = df.word1_kg_id[i]
        ent2 = df.word2_kg_id[i]
        if ent1 not in model or ent2 not in model:
            sims.append(np.nan)
            continue
        sims.append(model.similarity(ent1,ent2))
    df[name] = sims

# %%
df.to_csv(path_or_buf = "{}/wordsim_with_embedding_scores_out.csv".format(output_dir), index = False)

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(df)
# Out:
#             Word 1 word1_kg_id  \
# 0        admission     Q847337
# 1          alcohol        Q154
# 2         aluminum        Q663
# 3     announcement     Q567303
# 4     announcement     Q567303
# 5     announcement     Q567303
# 6     announcement     Q567303
# 7           Arafat      Q34211
# 8           Arafat      Q34211
# 9     architecture      Q12271
# 10     arrangement    Q2006324
# 11          asylum     Q210999
# 12      atmosphere       Q3230
# 13         attempt   Q12897867
# 14            baby        Q998
# 15            bank      Q22687
# 16        baseball       Q5369
# 17             bed      Q42177
# 18       benchmark     Q367293
# 19            bird       Q5113
# 20            bird       Q5113
# 21          bishop      Q29182
# 22           board     Q865588
# 23            book        Q571
# 24            book        Q571
# 25          boxing      Q32112
# 26             boy       Q3010
# 27           bread       Q7802
# 28         brother   Q10861465
# 29     calculation     Q622821
# 30          canyon     Q150784
# 31             car       Q1420
# 32             car       Q1420
# 33            cell       Q7868
# 34        cemetery      Q39614
# 35         century        Q578
# 36         century        Q578
# 37    championship    Q1079023
# 38          chance    Q3851114
# 39          change    Q1150070
# 40           chord     Q188191
# 41          closet     Q106106
# 42           coast      Q93352
# 43           coast      Q93352
# 44           coast      Q93352
# 45         company    Q6881511
# 46     competition     Q841654
# 47        computer         Q68
# 48        computer         Q68
# 49        computer         Q68
# 50        computer         Q68
# 51        computer         Q68
# 52         concert     Q182832
# 53        consumer      Q22855
# 54        consumer      Q22855
# 55         country       Q6256
# 56           crane     Q178692
# 57          credit     Q305253
# 58          credit     Q305253
# 59        cucumber    Q2735883
# 60             cup      Q81727
# 61             cup      Q81727
# 62             cup      Q81727
# 63             cup      Q81727
# 64             cup      Q81727
# 65             cup      Q81727
# 66             cup      Q81727
# 67             cup      Q81727
# 68             cup      Q81727
# 69             cup      Q81727
# 70        currency       Q8142
# 71             day        Q573
# 72             day        Q573
# 73           death          Q4
# 74           death          Q4
# 75      decoration    Q6149036
# 76           delay   Q21075709
# 77           delay   Q21075709
# 78      deployment    Q1308677
# 79      deployment    Q1308677
# 80     development   Q26132748
# 81       direction    Q2151613
# 82      disability      Q12131
# 83        disaster    Q3839081
# 84       discovery   Q12772819
# 85        dividend   Q55091473
# 86        dividend     Q181201
# 87          doctor      Q39631
# 88          doctor      Q39631
# 89          doctor      Q39631
# 90          dollar       Q4917
# 91          dollar       Q4917
# 92          dollar       Q4917
# 93          dollar       Q4917
# 94           drink      Q40050
# 95           drink      Q40050
# 96           drink      Q40050
# 97           drink      Q40050
# 98           drink      Q40050
# 99            drug      Q12140
# 100         energy      Q11379
# 101         energy      Q11379
# 102         energy      Q11379
# 103    environment    Q2249676
# 104      equipment   Q16798631
# 105        exhibit   Q11985689
# 106     experience    Q1355387
# 107         family       Q8436
# 108            FBI       Q8333
# 109            FBI       Q8333
# 110      fertility     Q964401
# 111       fighting     Q650711
# 112           five        Q203
# 113          focus   Q63540903
# 114           food       Q2095
# 115           food       Q2095
# 116           food       Q2095
# 117       football       Q2736
# 118       football       Q2736
# 119       football       Q2736
# 120         forest       Q4421
# 121           fuck      Q32341
# 122        furnace    Q1709184
# 123           game      Q11410
# 124           game      Q11410
# 125           game      Q11410
# 126           game      Q11410
# 127           game      Q11410
# 128            gem      Q83437
# 129         gender      Q48277
# 130          glass      Q11469
# 131          glass      Q11469
# 132     government       Q7188
# 133       governor      Q48352
# 134       governor      Q48352
# 135        grocery     Q951964
# 136        Harvard      Q13371
# 137       hospital      Q16917
# 138          hotel      Q27686
# 139        hundred      Q37413
# 140          image     Q478798
# 141   impartiality    Q3149193
# 142  investigation   Q21004260
# 143       investor     Q557880
# 144         jaguar      Q30055
# 145         jaguar      Q35694
# 146       Japanese   Q58893412
# 147      Jerusalem       Q1218
# 148      Jerusalem       Q1218
# 149        journal      Q49850
# 150        journey      Q61509
# 151        journey      Q61509
# 152           king      Q12097
# 153           king      Q12097
# 154           king      Q12097
# 155            lad       Q3010
# 156            lad       Q3010
# 157            law       Q7748
# 158         lawyer      Q40348
# 159      liability    Q1274115
# 160           life          Q3
# 161           life          Q3
# 162           life          Q3
# 163           line    Q1228250
# 164        listing     Q798505
# 165        listing     Q798505
# 166        lobster   Q61864890
# 167        lobster   Q61864890
# 168           love        Q316
# 169          lover        Q316
# 170         luxury   Q10953913
# 171       magician   Q15855449
# 172            man       Q8441
# 173            man       Q8441
# 174       Maradona      Q17515
# 175       marathon      Q40244
# 176           Mars        Q111
# 177          media     Q340169
# 178          media     Q340169
# 179          media     Q340169
# 180         Mexico         Q96
# 181         midday     Q168182
# 182           mile     Q253276
# 183       minister      Q83307
# 184       ministry     Q192350
# 185       minority     Q769696
# 186          money       Q1368
# 187          money       Q1368
# 188          money       Q1368
# 189          money       Q1368
# 190          money       Q1368
# 191          money       Q1368
# 192          money       Q1368
# 193          money       Q1368
# 194          money       Q1368
# 195          money       Q1368
# 196          money       Q1368
# 197          money       Q1368
# 198          money       Q1368
# 199          money       Q1368
# 200          money       Q1368
# 201          money       Q1368
# 202           monk     Q733786
# 203           monk     Q733786
# 204          month       Q5151
# 205       morality      Q48324
# 206       morality      Q48324
# 207          movie      Q11424
# 208          movie      Q11424
# 209          movie      Q11424
# 210          movie      Q11424
# 211         murder     Q132821
# 212         museum      Q33506
# 213          music        Q638
# 214         nature       Q7860
# 215         nature       Q7860
# 216        network    Q1900326
# 217           news      Q38926
# 218           noon     Q168182
# 219    observation     Q193181
# 220            oil      Q22656
# 221           OPEC       Q7795
# 222           OPEC       Q7795
# 223          opera       Q1344
# 224          opera       Q1344
# 225          peace        Q454
# 226          peace        Q454
# 227          peace        Q454
# 228          phone      Q17517
# 229        physics        Q413
# 230        physics        Q413
# 231          plane      Q17285
# 232         planet        Q634
# 233         planet        Q634
# 234         planet        Q634
# 235         planet        Q634
# 236         planet        Q634
# 237         planet        Q634
# 238         planet        Q634
# 239     population    Q2625603
# 240    possibility   Q21170479
# 241       practice     Q334600
# 242      precedent   Q19269277
# 243      precedent   Q19269277
# 244      precedent   Q19269277
# 245      precedent   Q19269277
# 246      precedent   Q19269277
# 247      precedent   Q19269277
# 248      precedent     Q665141
# 249      prejudice     Q179742
# 250   preservation    Q1479406
# 251      president      Q30461
# 252        problem     Q621184
# 253        problem     Q621184
# 254     production     Q739302
# 255     production     Q739302
# 256      professor     Q121594
# 257      professor     Q121594
# 258         profit      Q26911
# 259         profit      Q26911
# 260     psychology       Q9418
# 261     psychology       Q9418
# 262     psychology       Q9418
# 263     psychology       Q9418
# 264     psychology       Q9418
# 265     psychology       Q9418
# 266     psychology       Q9418
# 267     psychology       Q9418
# 268     psychology       Q9418
# 269     psychology       Q9418
# 270     psychology       Q9418
# 271     psychology       Q9418
# 272         reason    Q2574811
# 273         reason    Q2574811
# 274         record      Q49848
# 275   registration    Q2399307
# 276         report   Q10870555
# 277           rock      Q11399
# 278        rooster    Q2216236
# 279         school       Q3914
# 280        seafood     Q192935
# 281        seafood     Q192935
# 282        seafood     Q192935
# 283      secretary      Q80687
# 284          seven      Q23350
# 285          shore     Q468756
# 286         shower       Q7863
# 287         shower       Q7863
# 288           sign    Q3695082
# 289      situation    Q2141565
# 290      situation    Q2141565
# 291           size     Q322481
# 292           skin       Q1074
# 293          smart      Q83500
# 294          smart      Q83500
# 295           soap      Q23739
# 296          space        Q107
# 297          space        Q107
# 298          start     Q529711
# 299          start     Q529711
# 300          stock    Q1196314
# 301          stock    Q1196314
# 302          stock    Q1196314
# 303          stock    Q1196314
# 304          stock    Q1196314
# 305          stock    Q1196314
# 306          stock    Q1196314
# 307         street      Q79007
# 308         street      Q79007
# 309         street      Q79007
# 310         street      Q79007
# 311         stroke      Q12202
# 312        student      Q48282
# 313         summer       Q1313
# 314         summer       Q1313
# 315      telephone      Q11035
# 316     television        Q289
# 317     television        Q289
# 318         tennis        Q847
# 319      territory     Q183366
# 320      territory     Q183366
# 321        theater      Q11635
# 322          tiger      Q19939
# 323          tiger      Q19939
# 324          tiger      Q19939
# 325          tiger      Q19939
# 326          tiger      Q19939
# 327          tiger      Q19939
# 328          tiger      Q19939
# 329          tiger      Q19939
# 330          tiger      Q19939
# 331          tiger      Q19939
# 332           tool      Q39546
# 333          train        Q870
# 334         travel      Q61509
# 335      treatment     Q179661
# 336           type   Q21146257
# 337         victim    Q1851760
# 338          video   Q98069877
# 339         viewer   Q11812495
# 340          vodka        Q374
# 341          vodka        Q374
# 342      volunteer   Q24716636
# 343            war        Q198
# 344         weapon        Q728
# 345        weather      Q11663
# 346      Wednesday        Q128
# 347           wood        Q287
# 348           word       Q8171
#
#                                         word1_kg_label  \
# 0                                           confession
# 1                                   alcoholic beverage
# 2                                            aluminium
# 3                                         announcement
# 4                                         announcement
# 5                                         announcement
# 6                                         announcement
# 7                                        Yasser Arafat
# 8                                        Yasser Arafat
# 9                                         architecture
# 10                                           agreement
# 11                                psychiatric hospital
# 12                                 atmosphere of Earth
# 13                                             attempt
# 14                                                baby
# 15                                                bank
# 16                                            baseball
# 17                                                 bed
# 18                                          convention
# 19                                                bird
# 20                                                bird
# 21                                              bishop
# 22                                           committee
# 23                                                book
# 24                                                book
# 25                                              boxing
# 26                                                 boy
# 27                                               bread
# 28                                             brother
# 29                                         calculation
# 30                                              canyon
# 31                                           motor car
# 32                                           motor car
# 33                                                cell
# 34                                            cemetery
# 35                                             century
# 36                                             century
# 37                                        championship
# 38                                         opportunity
# 39                                              change
# 40                                               chord
# 41                                            wardrobe
# 42                                               coast
# 43                                               coast
# 44                                               coast
# 45                                          enterprise
# 46                                         competition
# 47                                            computer
# 48                                            computer
# 49                                            computer
# 50                                            computer
# 51                                            computer
# 52                                             concert
# 53                                            consumer
# 54                                            consumer
# 55                                             country
# 56                                               crane
# 57                                              credit
# 58                                              credit
# 59                                            cucumber
# 60                                                 cup
# 61                                                 cup
# 62                                                 cup
# 63                                                 cup
# 64                                                 cup
# 65                                                 cup
# 66                                                 cup
# 67                                                 cup
# 68                                                 cup
# 69                                                 cup
# 70                                            currency
# 71                                                 day
# 72                                                 day
# 73                                               death
# 74                                               death
# 75                                          decoration
# 76                                               delay
# 77                                               delay
# 78                                          deployment
# 79                                          deployment
# 80                                         development
# 81                                           direction
# 82                                          disability
# 83                                            disaster
# 84                                           discovery
# 85                                            dividend
# 86                                            dividend
# 87                                           physician
# 88                                           physician
# 89                                           physician
# 90                                United States dollar
# 91                                United States dollar
# 92                                United States dollar
# 93                                United States dollar
# 94                                               drink
# 95                                               drink
# 96                                               drink
# 97                                               drink
# 98                                               drink
# 99                                          medication
# 100                                             energy
# 101                                             energy
# 102                                             energy
# 103                                        environment
# 104                                          equipment
# 105                                            exhibit
# 106                                         experience
# 107                                             family
# 108                    Federal Bureau of Investigation
# 109                    Federal Bureau of Investigation
# 110                                          fertility
# 111                                             combat
# 112                                                  5
# 113                                        focal ppint
# 114                                               food
# 115                                               food
# 116                                               food
# 117                               association football
# 118                               association football
# 119                               association football
# 120                                             forest
# 121                                               fuck
# 122                                    heating furnace
# 123                                               game
# 124                                               game
# 125                                               game
# 126                                               game
# 127                                               game
# 128                                           gemstone
# 129                                             gender
# 130                                              glass
# 131                                              glass
# 132                                         government
# 133                                      head of state
# 134                                      head of state
# 135                                       food product
# 136                                 Harvard University
# 137                                           hospital
# 138                                              hotel
# 139                                            hundred
# 140                                              image
# 141                                       impartiality
# 142                                            inquiry
# 143                                           investor
# 144                                        Jaguar Cars
# 145                                      Panthera onca
# 146                                           Japanese
# 147                                          Jerusalem
# 148                                          Jerusalem
# 149                                            journal
# 150                                             travel
# 151                                             travel
# 152                                               king
# 153                                               king
# 154                                               king
# 155                                                boy
# 156                                                boy
# 157                                                law
# 158                                             lawyer
# 159                                     responsibility
# 160                                               life
# 161                                               life
# 162                                               life
# 163                                               line
# 164                                            listing
# 165                                            listing
# 166                                            lobster
# 167                                            lobster
# 168                                               love
# 169                                               love
# 170                                             luxury
# 171                                           magician
# 172                                                man
# 173                                                man
# 174                                     Diego Maradona
# 175                                           marathon
# 176                                               Mars
# 177                               communication medium
# 178                               communication medium
# 179                               communication medium
# 180                                             Mexico
# 181                                               noon
# 182                                               mile
# 183                                           minister
# 184                                           ministry
# 185                                    ethnic minority
# 186                                              money
# 187                                              money
# 188                                              money
# 189                                              money
# 190                                              money
# 191                                              money
# 192                                              money
# 193                                              money
# 194                                              money
# 195                                              money
# 196                                              money
# 197                                              money
# 198                                              money
# 199                                              money
# 200                                              money
# 201                                              money
# 202                                               monk
# 203                                               monk
# 204                                              month
# 205                                           morality
# 206                                           morality
# 207                                               film
# 208                                               film
# 209                                               film
# 210                                               film
# 211                                             murder
# 212                                             museum
# 213                                              music
# 214                                             nature
# 215                                             nature
# 216                                            network
# 217                                               news
# 218                                               noon
# 219                                        observation
# 220                                          petroleum
# 221  Organization of the Petroleum Exporting Countries
# 222  Organization of the Petroleum Exporting Countries
# 223                                              opera
# 224                                              opera
# 225                                              peace
# 226                                              peace
# 227                                              peace
# 228                                       mobile phone
# 229                                            physics
# 230                                            physics
# 231                                              plane
# 232                                             planet
# 233                                             planet
# 234                                             planet
# 235                                             planet
# 236                                             planet
# 237                                             planet
# 238                                             planet
# 239                                         population
# 240                                        possibility
# 241                                           practice
# 242                                              first
# 243                                              first
# 244                                              first
# 245                                              first
# 246                                              first
# 247                                              first
# 248                                          precedent
# 249                                          prejudice
# 250                                       preservation
# 251                                          president
# 252                                            problem
# 253                                            problem
# 254                                         production
# 255                                         production
# 256                                          professor
# 257                                          professor
# 258                                    economic profit
# 259                                    economic profit
# 260                                         psychology
# 261                                         psychology
# 262                                         psychology
# 263                                         psychology
# 264                                         psychology
# 265                                         psychology
# 266                                         psychology
# 267                                         psychology
# 268                                         psychology
# 269                                         psychology
# 270                                         psychology
# 271                                         psychology
# 272                                              cause
# 273                                              cause
# 274                                           document
# 275                                       registration
# 276                                             report
# 277                                         rock music
# 278                                            rooster
# 279                                             school
# 280                                            seafood
# 281                                            seafood
# 282                                            seafood
# 283                                          secretary
# 284                                                  7
# 285                                              shore
# 286                                             shower
# 287                                             shower
# 288                                               sign
# 289                                          situation
# 290                                          situation
# 291                                               size
# 292                                               skin
# 293                                       intelligence
# 294                                       intelligence
# 295                                         soap opera
# 296                                              space
# 297                                              space
# 298                                          beginning
# 299                                          beginning
# 300                                              stock
# 301                                              stock
# 302                                              stock
# 303                                              stock
# 304                                              stock
# 305                                              stock
# 306                                              stock
# 307                                             street
# 308                                             street
# 309                                             street
# 310                                             street
# 311                                             stroke
# 312                                            student
# 313                                             summer
# 314                                             summer
# 315                                          telephone
# 316                                         television
# 317                                         television
# 318                                             tennis
# 319                                          territory
# 320                                          territory
# 321                                            theater
# 322                                              tiger
# 323                                              tiger
# 324                                              tiger
# 325                                              tiger
# 326                                              tiger
# 327                                              tiger
# 328                                              tiger
# 329                                              tiger
# 330                                              tiger
# 331                                              tiger
# 332                                               tool
# 333                                              train
# 334                                             travel
# 335                                          treatment
# 336                                               type
# 337                                             victim
# 338                                              video
# 339                                             viewer
# 340                                              vodka
# 341                                              vodka
# 342                                          volunteer
# 343                                                war
# 344                                             weapon
# 345                                            weather
# 346                                          Wednesday
# 347                                               wood
# 348                                               word
#
#                                   word1_kg_description          Word 2  \
# 0    statement made by a person or a group of perso...          ticket
# 1         drink containing alcohols, typically ethanol       chemistry
# 2    metallic chemical element of silvery appearanc...           metal
# 3    printed, spoken, or published statement or not...          effort
# 4    printed, spoken, or published statement or not...            news
# 5    printed, spoken, or published statement or not...      production
# 6    printed, spoken, or published statement or not...         warning
# 7                         former Palestinian President           peace
# 8                         former Palestinian President          terror
# 9    both the process and product of planning, desi...         century
# 10   understanding between entities to follow a spe...   accommodation
# 11   hospitals or wards specializing in the treatme...        madhouse
# 12         layer of gases surrounding the planet Earth       landscape
# 13              action whose success is not guaranteed           peace
# 14                     very young offspring of a human          mother
# 15                               financial institution           money
# 16   American sport in which teams compete to score...          season
# 17   piece of furniture used as a place to sleep or...          closet
# 18   set of agreed, stipulated or generally accepte...           index
# 19                                  class of tetrapods            cock
# 20                                  class of tetrapods           crane
# 21   ordained or consecrated member of the Christia...           rabbi
# 22   body of one or more persons that is subordinat...  recommendation
# 23   a written text that can be published in printe...         library
# 24   a written text that can be published in printe...           paper
# 25                                        combat sport           round
# 26                                    young male human             lad
# 27                   staple food prepared from a dough          butter
# 28   male sibling. Avoid using with \relative\ (P10...            monk
# 29   deliberate process that transforms inputs to o...     computation
# 30                          deep ravine between cliffs       landscape
# 31   road vehicle powered by a motor to carry drive...      automobile
# 32   road vehicle powered by a motor to carry drive...          flight
# 33   the basic structural and functional unit of al...           phone
# 34                                     place of burial        woodland
# 35                      unit of time lasting 100 years          nation
# 36                      unit of time lasting 100 years            year
# 37   various forms of competition in which the aim ...      tournament
# 38           likelihood of a favorable event occurring     credibility
# 39   process, event or action that deviates from th...        attitude
# 40   geometric line segment whose endpoints both li...           smile
# 41                                     storage cabinet         clothes
# 42              area where land meets the sea or ocean          forest
# 43              area where land meets the sea or ocean            hill
# 44              area where land meets the sea or ocean           shore
# 45   for-profit organizational unit producing goods...           stock
# 46                        contest for a prize or award           price
# 47   general-purpose device for performing arithmet...        internet
# 48   general-purpose device for performing arithmet...        keyboard
# 49   general-purpose device for performing arithmet...      laboratory
# 50   general-purpose device for performing arithmet...            news
# 51   general-purpose device for performing arithmet...        software
# 52                           live performance of music        virtuoso
# 53   person or group of people that are the final u...      confidence
# 54   person or group of people that are the final u...          energy
# 55   the distinct region in geography; a broad term...         citizen
# 56                                     type of machine       implement
# 57                   amount added to an account ledger            card
# 58                   amount added to an account ledger     information
# 59                             fruit used as vegetable          potato
# 60             open-top container used to hold liquids         article
# 61             open-top container used to hold liquids        artifact
# 62             open-top container used to hold liquids          coffee
# 63             open-top container used to hold liquids           drink
# 64             open-top container used to hold liquids          entity
# 65             open-top container used to hold liquids            food
# 66             open-top container used to hold liquids          liquid
# 67             open-top container used to hold liquids          object
# 68             open-top container used to hold liquids       substance
# 69             open-top container used to hold liquids       tableware
# 70   generally accepted medium of exchange for good...          market
# 71   unit of time lasting 24 hours, derived from th...            dawn
# 72   unit of time lasting 24 hours, derived from th...          summer
# 73              permanent cessation of vital functions          inmate
# 74              permanent cessation of vital functions             row
# 75                               any type of adornment           valor
# 76   period of time between when an event is expect...            news
# 77   period of time between when an event is expect...          racism
# 78               task-oriented activity of task forces       departure
# 79               task-oriented activity of task forces      withdrawal
# 80      process of developing; growth, directed change           issue
# 81   information contained in the relative position...     combination
# 82   impairments, activity limitations, and partici...           death
# 83   hazard resulting in an event causing significa...            area
# 84                      act of detecting something new           space
# 85               in a division, quantity to be divided     calculation
# 86   Payment made by a corporation to its sharehold...         payment
# 87                 professional who practices medicine       liability
# 88                 professional who practices medicine           nurse
# 89                 professional who practices medicine       personnel
# 90            currency of the United States of America            buck
# 91            currency of the United States of America            loss
# 92            currency of the United States of America          profit
# 93            currency of the United States of America             yen
# 94   kind of liquid which is specifically prepared ...             car
# 95   kind of liquid which is specifically prepared ...             ear
# 96   kind of liquid which is specifically prepared ...             eat
# 97   kind of liquid which is specifically prepared ...          mother
# 98   kind of liquid which is specifically prepared ...           mouth
# 99   substance used to diagnose, cure, treat, or pr...           abuse
# 100  quantitative physical property transferred to ...          crisis
# 101  quantitative physical property transferred to ...      laboratory
# 102  quantitative physical property transferred to ...       secretary
# 103           surrounding of an organism or population         ecology
# 104  collective term for all items that are require...           maker
# 105  object displayed to demonstrate a concept or s...     memorabilia
# 106  emotionally significant event in the individua...           music
# 107  group of people affiliated by consanguinity, a...        planning
# 108               United States law enforcement agency     fingerprint
# 109               United States law enforcement agency   investigation
# 110            natural capability to produce offspring             egg
# 111  purposeful violent conflict, typically refers ...       defeating
# 112                                     natural number           month
# 113                                                NaN            life
# 114  any substance consumed to provide nutritional ...           fruit
# 115  any substance consumed to provide nutritional ...     preparation
# 116  any substance consumed to provide nutritional ...         rooster
# 117  team field sport with the objective to score p...      basketball
# 118  team field sport with the objective to score p...          soccer
# 119  team field sport with the objective to score p...          tennis
# 120  dense collection of trees covering a relativel...       graveyard
# 121    verb referring to the act of sexual intercourse             sex
# 122                device used for heating in industry           stove
# 123  a structured form of play, usually for enterta...          defeat
# 124  a structured form of play, usually for enterta...           round
# 125  a structured form of play, usually for enterta...          series
# 126  a structured form of play, usually for enterta...            team
# 127  a structured form of play, usually for enterta...         victory
# 128              piece of mineral used to make jewelry           jewel
# 129  range of physical, mental, and behavioral char...        equality
# 130  amorphous solid that exhibits a glass transiti...        magician
# 131  amorphous solid that exhibits a glass transiti...           metal
# 132  system or group of people governing an organiz...          crisis
# 133  official who holds the highest-ranked executiv...       interview
# 134  official who holds the highest-ranked executiv...          office
# 135  product consisting of food intended for human ...           money
# 136  private research university in Cambridge, Mass...            Yale
# 137                            health care institution  infrastructure
# 138  business enterprise that provides lodging in a...     reservation
# 139                                      natual number         percent
# 140  artifact that depicts or records visual percep...         surface
# 141  principle of justice holding that decisions sh...        interest
# 142  process that has the aim of augmenting knowled...          effort
# 143  person who allocates capital with the expectat...         earning
# 144                         former British car company             car
# 145          species of big cat native to the Americas             cat
# 146                     citizens or residents of Japan        American
# 147                      ancient city in the Near East          Israel
# 148                      ancient city in the Near East     Palestinian
# 149                                     written medium     association
# 150  movement of people between relatively distant ...             car
# 151  movement of people between relatively distant ...          voyage
# 152                              class of male monarch         cabbage
# 153                              class of male monarch           queen
# 154                              class of male monarch            rook
# 155                                   young male human         brother
# 156                                   young male human          wizard
# 157  system of rules and guidelines, generally back...          lawyer
# 158  legal professional who helps clients and repre...        evidence
# 159  state or fact of being responsible, of having ...       insurance
# 160  matter capable of extracting energy from the e...           death
# 161  matter capable of extracting energy from the e...          lesson
# 162  matter capable of extracting energy from the e...            term
# 163     general concept of a line (curved or straight)       insurance
# 164  In corporate finance, the company\s shares bei...        category
# 165  In corporate finance, the company\s shares bei...       proximity
# 166                                          shellfish            food
# 167                                          shellfish            wine
# 168        strong, positive emotion based on affection             sex
# 169        strong, positive emotion based on affection         quarrel
# 170  Behavior, expenses or equipment that far excee...             car
# 171  entertainer who performs magic by creating the...          wizard
# 172                                   male adult human        governor
# 173                                   male adult human           woman
# 174  Argentine association football player and mana...        football
# 175  long-distance running event with an official d...          sprint
# 176                         fourth planet from the Sun       scientist
# 177  storage and delivering agent of information or...            gain
# 178  storage and delivering agent of information or...           radio
# 179  storage and delivering agent of information or...         trading
# 180  sovereign state in the southern portion of Nor...          Brazil
# 181                          12 o\clock in the daytime            noon
# 182                                     unit of length       kilometer
# 183  politician who holds significant civil public ...           party
# 184  specialised civil organisation responsible for...         culture
# 185  group within a community which has different n...           peace
# 186               object or record accepted as payment            bank
# 187               object or record accepted as payment            cash
# 188               object or record accepted as payment            cash
# 189               object or record accepted as payment            cash
# 190               object or record accepted as payment            cash
# 191               object or record accepted as payment        currency
# 192               object or record accepted as payment         deposit
# 193               object or record accepted as payment          dollar
# 194               object or record accepted as payment      laundering
# 195               object or record accepted as payment       operation
# 196               object or record accepted as payment      possession
# 197               object or record accepted as payment      possession
# 198               object or record accepted as payment        property
# 199               object or record accepted as payment        property
1.000000  1.000000  1.000000  1.000000  1.000000  1.000000       NaN
# 333  0.507468  0.378466  0.654112  0.508850  0.574478  0.438859       NaN
# 334  0.400234  0.638347  0.682683  0.136251  0.819062  0.621778       NaN
# 335  0.349674  0.113343  0.457537  0.028627  0.234182  0.118518       NaN
# 336  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000       NaN
# 337  0.425303  0.490311  0.697222  0.000436  0.476111  0.391917       NaN
# 338  0.530936  0.260283  0.679086  0.649235  0.641351  0.451779       NaN
# 339  0.356639  0.357562  0.528582  0.000521       NaN       NaN       NaN
# 340  0.605971  0.748929  0.743762  0.881906  0.789710  0.721035       NaN
# 341  0.543343  0.714010  0.827655  0.915257  0.851578  0.803200       NaN
# 342  0.215129  0.216679  0.554303  0.042977  0.460843  0.378608       NaN
# 343  0.397487  0.110370  0.484127  0.006907  0.581985  0.409586       NaN
# 344  0.229913  0.238127  0.477929  0.014834  0.511025  0.405434       NaN
# 345  0.516799  0.255450  0.573260  0.071395  0.503114  0.452679       NaN
# 346  0.268788 -0.011625  0.310457  0.028485  0.371400  0.212589       NaN
# 347  0.356130  0.090342  0.817334  0.005343  0.481708  0.324104       NaN
# 348  0.450524  0.234803  0.663337  0.029872  0.475150  0.436262       NaN
#
#             S
# 0    0.589556
# 1   -0.011093
# 2    0.154339
# 3         NaN
# 4    0.024330
# 5    0.139569
# 6         NaN
# 7    0.083322
# 8         NaN
# 9    0.159141
# 10        NaN
# 11   1.000000
# 12   0.040356
# 13        NaN
# 14   0.383003
# 15   0.096637
# 16  -0.024828
# 17        NaN
# 18        NaN
# 19  -0.087320
# 20   0.023802
# 21   0.298525
# 22        NaN
# 23   0.316186
# 24   0.304198
# 25  -0.067720
# 26   1.000000
# 27   0.040624
# 28   0.227183
# 29        NaN
# 30  -0.024123
# 31   1.000000
# 32        NaN
# 33   0.035580
# 34        NaN
# 35   0.226770
# 36   0.129146
# 37        NaN
# 38        NaN
# 39        NaN
# 40        NaN
# 41  -0.026479
# 42  -0.076970
# 43   0.181881
# 44   0.039592
# 45  -0.127648
# 46        NaN
# 47   0.182200
# 48   0.020447
# 49  -0.019755
# 50   0.004066
# 51   0.725218
# 52  -0.001801
# 53        NaN
# 54   0.084557
# 55   0.117883
# 56   0.077308
# 57        NaN
# 58        NaN
# 59  -0.046103
# 60        NaN
# 61        NaN
# 62        NaN
# 63        NaN
# 64        NaN
# 65        NaN
# 66        NaN
# 67        NaN
# 68        NaN
# 69        NaN
# 70   0.022096
# 71   0.057673
# 72  -0.044504
# 73  -0.065745
# 74        NaN
# 75   0.002802
# 76        NaN
# 77        NaN
# 78        NaN
# 79        NaN
# 80        NaN
# 81        NaN
# 82  -0.026465
# 83  -0.033025
# 84        NaN
# 85        NaN
# 86        NaN
# 87        NaN
# 88  -0.000347
# 89   0.037544
# 90  -0.085682
# 91        NaN
# 92   0.045050
# 93   0.037766
# 94   0.005948
# 95  -0.086533
# 96  -0.042115
# 97  -0.047598
# 98   0.079915
# 99   0.140802
# 100 -0.005784
# 101 -0.012442
# 102  0.208442
# 103  0.017146
# 104  0.035767
# 105       NaN
# 106       NaN
# 107  0.255233
# 108  0.238535
# 109 -0.031348
# 110  0.159281
# 111       NaN
# 112  0.057429
# 113       NaN
# 114 -0.002712
# 115  0.082098
# 116  0.127465
# 117  0.257873
# 118  1.000000
# 119  0.239634
# 120  0.057563
# 121       NaN
# 122 -0.044786
# 123       NaN
# 124  0.099397
# 125       NaN
# 126  0.069483
# 127  0.172481
# 128  1.000000
# 129       NaN
# 130  0.210343
# 131  0.005325
# 132  0.084554
# 133  0.111658
# 134  0.051307
# 135  0.032777
# 136 -0.090809
# 137 -0.099240
# 138       NaN
# 139  0.032667
# 140       NaN
# 141       NaN
# 142       NaN
# 143       NaN
# 144  0.243298
# 145  0.005971
# 146  0.202245
# 147  0.381247
# 148  0.332307
# 149       NaN
# 150  0.198250
# 151       NaN
# 152       NaN
# 153  0.233289
# 154  0.029469
# 155 -0.065554
# 156 -0.117522
# 157  0.233644
# 158 -0.031815
# 159       NaN
# 160  0.094918
# 161 -0.039584
# 162  0.005717
# 163       NaN
# 164       NaN
# 165       NaN
# 166 -0.074422
# 167  0.107896
# 168  0.201057
# 169       NaN
# 170 -0.108007
# 171  0.659215
# 172 -0.020686
# 173 -0.004750
# 174 -0.019664
# 175 -0.044093
# 176 -0.116619
# 177       NaN
# 178 -0.118991
# 179       NaN
# 180  0.758796
# 181       NaN
# 182  0.100284
# 183  0.248941
# 184  0.120063
# 185 -0.076137
# 186  0.096637
# 187  0.064961
# 188  0.064961
# 189  0.064961
# 190  0.064961
# 191 -0.046638
# 192 -0.021325
# 193 -0.085682
# 194 -0.040043
# 195       NaN
# 196  0.139037
# 197  0.139037
# 198  0.139037
# 199  0.139037
# 200  0.077052
# 201       NaN
# 202 -0.089357
# 203  0.022857
# 204  0.208686
# 205       NaN
# 206  0.036453
# 207  0.105902
# 208 -0.113171
# 209 -0.029682
# 210  0.296862
# 211  0.040275
# 212  0.013458
# 213 -0.080610
# 214  0.060336
# 215  0.192601
# 216       NaN
# 217       NaN
# 218       NaN
# 219  0.014175
# 220 -0.041464
# 221  0.157263
# 222 -0.010311
# 223 -0.048413
# 224       NaN
# 225  0.031819
# 226 -0.026156
# 227  0.036065
# 228  0.040727
# 229 -0.048312
# 230 -0.038747
# 231       NaN
# 232  0.271725
# 233  0.371136
# 234  0.141062
# 235  0.047674
# 236  0.218255
# 237  0.046965
# 238  0.715204
# 239       NaN
# 240       NaN
# 241 -0.101468
# 242       NaN
# 243       NaN
# 244       NaN
# 245       NaN
# 246       NaN
# 247       NaN
# 248  0.145484
# 249       NaN
# 250       NaN
# 251  0.002404
# 252  0.234833
# 253       NaN
# 254  0.045878
# 255       NaN
# 256  0.051070
# 257  0.111238
# 258       NaN
# 259       NaN
# 260 -0.176832
# 261 -0.046689
# 262  0.048322
# 263 -0.116855
# 264  0.226297
# 265  0.143904
# 266 -0.036758
# 267  0.212768
# 268  0.291289
# 269 -0.004282
# 270  0.292730
# 271  0.280661
# 272       NaN
# 273       NaN
# 274  0.259365
# 275       NaN
# 276       NaN
# 277 -0.062935
# 278       NaN
# 279       NaN
# 280 -0.044990
# 281 -0.021575
# 282 -0.129857
# 283  0.125238
# 284       NaN
# 285       NaN
# 286  0.174281
# 287  0.117993
# 288       NaN
# 289       NaN
# 290       NaN
# 291       NaN
# 292  0.241806
# 293  0.143758
# 294       NaN
# 295 -0.007473
# 296  0.047910
# 297 -0.059221
# 298       NaN
# 299       NaN
# 300 -0.047321
# 301 -0.069067
# 302  0.036476
# 303  0.010023
# 304  0.122241
# 305 -0.048622
# 306 -0.116384
# 307  0.390016
# 308       NaN
# 309  0.307382
# 310  0.179085
# 311 -0.091736
# 312  0.222889
# 313  0.044510
# 314 -0.100557
# 315 -0.099996
# 316  0.258778
# 317  0.123068
# 318  0.039887
# 319  0.066822
# 320 -0.034389
# 321  0.284597
# 322  0.173307
# 323  0.152200
# 324  0.095665
# 325  0.006552
# 326 -0.009905
# 327  0.000973
# 328  0.129802
# 329  0.095601
# 330  1.000000
# 331  0.080272
# 332  1.000000
# 333  0.188765
# 334       NaN
# 335       NaN
# 336       NaN
# 337       NaN
# 338       NaN
# 339       NaN
# 340 -0.033271
# 341  0.168746
# 342 -0.120954
# 343 -0.015297
# 344  0.032836
# 345  0.291257
# 346 -0.043554
# 347 -0.006403
# 348       NaN

# %%
for name, model in embedding_models.items():
    if "H" not in name:
        continue
    sims = []
    for i in range(len(df)):
        ent1 = df.g_qnode[i]
        ent2 = df.p_qnode[i]
        if ent1 not in model or ent2 not in model:
            sims.append(np.nan)
            continue
        sims.append(model.similarity(ent1,ent2))
    df[name] = sims

# %%
df.to_csv(path_or_buf = "{}/sim_with_embedding_scores_out.csv".format(output_dir), index = False)

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(df)
# Out:
#      Index    g_qnode    p_qnode                        q1_label  \
# 0       11     Q17221    Q189290                    spokesperson
# 1        3    Q702269   Q2285706                    professional
# 2        5   Q2285706     Q82955              head of government
# 3       11    Q107711    Q189290                     firefighter
# 4        3    Q702269     Q48352                    professional
# 5        5     Q48352     Q82955                   head of state
# 6        2   Q2285706     Q83307              head of government
# 7        2     Q48352     Q83307                   head of state
# 8       16   Q1251441     Q83307                          leader
# 9       11   Q9352089    Q189290                             spy
# 10      10    Q201948   Q1930187                          sniper
# 11      10   Q1414937   Q1930187                       combatant
# 12      19     Q82955  Q11499147                      politician
# 13      13    Q245065    Q327333  intergovernmental organization
# 14      15    Q245065    Q327333  intergovernmental organization
# 15      22    Q245065    Q327333  intergovernmental organization
# 16      23    Q245065    Q327333  intergovernmental organization
# 17      20    Q245065      Q7278  intergovernmental organization
# 18       3     Q17221   Q2285706                    spokesperson
# 19       1   Q2285706     Q17221              head of government
# 20       3     Q17221     Q48352                    spokesperson
# 21       1     Q48352     Q17221                   head of state
# 22       9   Q2285706    Q189290              head of government
# 23      13    Q245065      Q7188  intergovernmental organization
# 24      15    Q245065      Q7188  intergovernmental organization
# 25      22    Q245065      Q7188  intergovernmental organization
# 26      23    Q245065      Q7188  intergovernmental organization
# 27       9     Q48352    Q189290                   head of state
# 28       6    Q702269    Q215627                    professional
# 29      11    Q702269    Q189290                    professional
# 30      13    Q702492     Q22667                      urban area
# 31      15    Q702492     Q22667                      urban area
# 32      22    Q702492     Q22667                      urban area
# 33      23    Q702492     Q22667                      urban area
# 34      13    Q245065  Q10553309  intergovernmental organization
# 35      15    Q245065  Q10553309  intergovernmental organization
# 36      22    Q245065  Q10553309  intergovernmental organization
# 37      23    Q245065  Q10553309  intergovernmental organization
# 38      13    Q702492    Q327333                      urban area
# 39      15    Q702492    Q327333                      urban area
# 40      22    Q702492    Q327333                      urban area
# 41      23    Q702492    Q327333                      urban area
# 42       7    Q201948     Q83307                          sniper
# 43      20    Q702492      Q7278                      urban area
# 44      13       Q532     Q22667                         village
# 45      15       Q532     Q22667                         village
# 46      22       Q532     Q22667                         village
# 47      23       Q532     Q22667                         village
# 48      16  Q11499147     Q83307              political activist
# 49      21    Q245065  Q16334295  intergovernmental organization
# 50      21    Q702492  Q16334295                      urban area
# 51      13       Q532    Q327333                         village
# 52      15       Q532    Q327333                         village
# 53      22       Q532    Q327333                         village
# 54      23       Q532    Q327333                         village
# 55      20       Q532      Q7278                         village
# 56       7   Q1414937     Q83307                       combatant
# 57      13    Q702492      Q7188                      urban area
# 58      15    Q702492      Q7188                      urban area
# 59      22    Q702492      Q7188                      urban area
# 60      23    Q702492      Q7188                      urban area
# 61      17  Q16334295      Q7278                 group of humans
# 62       6   Q9352089    Q215627                             spy
# 63      13    Q702492  Q10553309                      urban area
# 64      15    Q702492  Q10553309                      urban area
# 65      22    Q702492  Q10553309                      urban area
# 66      23    Q702492  Q10553309                      urban area
# 67      13       Q532      Q7188                         village
# 68      15       Q532      Q7188                         village
# 69      22       Q532      Q7188                         village
# 70      23       Q532      Q7188                         village
# 71      21       Q532  Q16334295                         village
# 72      13       Q532  Q10553309                         village
# 73      15       Q532  Q10553309                         village
# 74      22       Q532  Q10553309                         village
# 75      23       Q532  Q10553309                         village
# 76       6     Q17221    Q215627                    spokesperson
# 77       6    Q107711    Q215627                     firefighter
# 78      13    Q245065     Q22667  intergovernmental organization
# 79      15    Q245065     Q22667  intergovernmental organization
# 80      22    Q245065     Q22667  intergovernmental organization
# 81      23    Q245065     Q22667  intergovernmental organization
# 82       3   Q9352089   Q2285706                             spy
# 83       4   Q2285706     Q47064              head of government
# 84       8   Q2285706     Q47064              head of government
# 85       3   Q9352089     Q48352                             spy
# 86       4     Q48352     Q47064                   head of state
# 87       8     Q48352     Q47064                   head of state
# 88       3    Q107711   Q2285706                     firefighter
# 89      13   Q1048835     Q22667    political territorial entity
# 90      15   Q1048835     Q22667    political territorial entity
# 91      22   Q1048835     Q22667    political territorial entity
# 92      23   Q1048835     Q22667    political territorial entity
# 42   0.476628  0.269697
# 43   0.411654  0.249073
# 44   0.220749  0.151808
# 45   0.220749  0.151808
# 46   0.220749  0.151808
# 47   0.220749  0.151808
# 48   0.788029  0.679339
# 49   0.436766  0.325647
# 50   0.340085  0.309309
# 51   0.165514  0.138242
# 52   0.165514  0.138242
# 53   0.165514  0.138242
# 54   0.165514  0.138242
# 55   0.211065  0.243336
# 56   0.574614  0.380200
# 57   0.585482  0.340512
# 58   0.585482  0.340512
# 59   0.585482  0.340512
# 60   0.585482  0.340512
# 61   0.418945  0.239390
# 62   0.360844  0.254340
# 63   0.500441  0.357624
# 64   0.500441  0.357624
# 65   0.500441  0.357624
# 66   0.500441  0.357624
# 67   0.305218  0.189139
# 68   0.305218  0.189139
# 69   0.305218  0.189139
# 70   0.305218  0.189139
# 71   0.162742  0.128256
# 72   0.422215  0.288712
# 73   0.422215  0.288712
# 74   0.422215  0.288712
# 75   0.422215  0.288712
# 76   0.364251  0.345237
# 77   0.321288  0.309943
# 78   0.430729  0.290107
# 79   0.430729  0.290107
# 80   0.430729  0.290107
# 81   0.430729  0.290107
# 82   0.493470  0.367798
# 83   0.650028  0.424659
# 84   0.650028  0.424659
# 85   0.539185  0.384187
# 86   0.700912  0.438408
# 87   0.700912  0.438408
# 88   0.511000  0.398301
# 89   0.504576  0.434141
# 90   0.504576  0.434141
# 91   0.504576  0.434141
# 92   0.504576  0.434141
# 93   0.469188  0.337830
# 94   0.393552  0.313163
# 95   0.401715  0.265611
# 96   0.376890  0.200355
# 97   0.842345  0.860134
# 98   0.221115  0.197852
# 99   0.356524  0.258628
# 100  0.303134  0.236608
# 101  0.581647  0.391748
# 102  0.291524  0.289911
# 103  0.454095  0.435736
# 104  0.454095  0.435736
# 105  0.454095  0.435736
# 106  0.454095  0.435736
# 107  0.756323  0.536187
# 108  0.756323  0.536187
# 109  0.756323  0.536187
# 110  0.756323  0.536187
# 111  0.594356  0.408742
# 112  0.594356  0.408742
# 113  0.594356  0.408742
# 114  0.594356  0.408742
# 115  0.445139  0.365898
# 116  0.528153  0.395248
# 117  0.772610  0.529669

# %%
list(df.groupby(by="Index")["H_5x8"].max())
# Out:
# [0.420357882976532,
#  0.7268710136413574,
#  0.420357882976532,
#  0.4384082555770874,
#  0.6394362449645996,
#  0.35159027576446533,
#  0.38020044565200806,
#  0.4384082555770874,
#  0.4243793189525604,
#  0.3309544026851654,
#  0.7093519568443298,
#  0.39174821972846985,
#  0.5734885931015015,
#  0.26561102271080017,
#  0.5734885931015015,
#  0.6793391704559326,
#  0.8601336479187012,
#  0.31316307187080383,
#  0.5979108810424805,
#  0.5036538243293762,
#  0.5296689867973328,
#  0.5734885931015015,
#  0.5734885931015015,
#  0.2586284279823303]

# %% [markdown]
# ## Compute Kendall's Tau and Spearman Coefficient

# %%
def print_agreement_coeffs(df, metric1_col, metric2_cols):
    no_nan_mask = np.full(len(df), True)
    for col in ([metric1_col] + metric2_cols):
        no_nan_mask = no_nan_mask & (~ np.array(np.isnan(df.loc[:,col])))
    df_no_nans = df.loc[no_nan_mask, :]

    metric1_order = np.array(df_no_nans.loc[:,metric1_col])

    headers = ["Metric 1", "Metric 2", "Kendall Tau", "Spearman"]
    rows = []
    for col in metric2_cols:
        metric2_order = np.array(df_no_nans.loc[:,col])
        tau, tau_p_val = stats.kendalltau(metric1_order, metric2_order)
        corr, corr_p_val = stats.spearmanr(metric1_order, metric2_order)
        row = [metric1_col, col, tau, corr]
        rows.append(row)

    print(tabulate(rows, headers=headers))
    
print("Comparing all methods to human baseline:\n")
print_agreement_coeffs(df, "Human (Mean)", ["complex", "transe", "text", "class"] + list(embedding_models.keys()))

print("\nComparing each of the embeddings against all  other methods:")
for name in embedding_models:
    print("\n")
    metric2_cols = ["Human (Mean)", "complex", "transe", "text", "class"] + [model_name for model_name in embedding_models if model_name != name]
    print_agreement_coeffs(df, name, metric2_cols)
# Out:
# Comparing all methods to human baseline:
#
# Metric 1      Metric 2      Kendall Tau    Spearman
# ------------  ----------  -------------  ----------
# Human (Mean)  complex         0.274725    0.389011
# Human (Mean)  transe          0.296703    0.406593
# Human (Mean)  text            0.340659    0.437363
# Human (Mean)  class           0.164835    0.243956
# Human (Mean)  H_3x6           0.56044     0.740659
# Human (Mean)  H_5x8           0.450549    0.613187
# Human (Mean)  A               0.0549451   0.0813187
# Human (Mean)  S               0.0549451   0.0197802
#
# Comparing each of the embeddings against all  other methods:
#
#
# Metric 1    Metric 2        Kendall Tau    Spearman
# ----------  ------------  -------------  ----------
# H_3x6       Human (Mean)       0.56044     0.740659
# H_3x6       complex            0.318681    0.450549
# H_3x6       transe             0.428571    0.556044
# H_3x6       text               0.340659    0.476923
# H_3x6       class              0.296703    0.402198
# H_3x6       H_5x8              0.714286    0.876923
# H_3x6       A                  0.186813    0.261538
# H_3x6       S                 -0.164835   -0.156044
#
#
# Metric 1    Metric 2        Kendall Tau    Spearman
# ----------  ------------  -------------  ----------
# H_5x8       Human (Mean)       0.450549   0.613187
# H_5x8       complex            0.120879   0.230769
# H_5x8       transe             0.318681   0.336264
# H_5x8       text               0.142857   0.230769
# H_5x8       class              0.186813   0.30989
# H_5x8       H_3x6              0.714286   0.876923
# H_5x8       A                  0.164835   0.226374
# H_5x8       S                 -0.010989   0.0021978
#
#
# Metric 1    Metric 2        Kendall Tau    Spearman
# ----------  ------------  -------------  ----------
# A           Human (Mean)      0.0549451   0.0813187
# A           complex           0.340659    0.415385
# A           transe            0.406593    0.551648
# A           text              0.362637    0.6
# A           class             0.406593    0.441758
# A           H_3x6             0.186813    0.261538
# A           H_5x8             0.164835    0.226374
# A           S                 0.296703    0.41978
#
#
# Metric 1    Metric 2        Kendall Tau    Spearman
# ----------  ------------  -------------  ----------
# S           Human (Mean)      0.0549451   0.0197802
# S           complex           0.164835    0.252747
# S           transe           -0.0769231  -0.169231
# S           text             -0.032967   -0.0417582
# S           class             0.0549451   0.0681319
# S           H_3x6            -0.164835   -0.156044
# S           H_5x8            -0.010989    0.0021978
# S           A                 0.296703    0.41978

# %%
def print_agreement_coeffs(df, metric1_col, metric2_cols):

    metric1_order = np.array(df.loc[:,metric1_col])

    headers = ["Metric 1", "Metric 2", "Kendall Tau", "Spearman"]
    rows = []
    for col in metric2_cols:
        metric2_order = np.array(df.loc[:,col])
        tau, tau_p_val = stats.kendalltau(metric1_order, metric2_order, nan_policy="omit")
        corr, corr_p_val = stats.spearmanr(metric1_order, metric2_order, nan_policy="omit")
        row = [metric1_col, col, tau, corr]
        rows.append(row)

    print(tabulate(rows, headers=headers))
    
print("Comparing all methods to human baseline:\n")
print_agreement_coeffs(df, "Human (Mean)", ["complex", "transe", "text", "class"] + list(embedding_models.keys()))

print("\nComparing each of the embeddings against all  other methods:")
for name in embedding_models:
    print("\n")
    metric2_cols = ["Human (Mean)", "complex", "transe", "text", "class"] + [model_name for model_name in embedding_models if model_name != name]
    print_agreement_coeffs(df, name, metric2_cols)
# Out:
# Comparing all methods to human baseline:
#
# Metric 1      Metric 2      Kendall Tau    Spearman
# ------------  ----------  -------------  ----------
# Human (Mean)  complex          0.313876    0.455019
# Human (Mean)  transe           0.235773    0.344647
# Human (Mean)  text             0.433488    0.608956
# Human (Mean)  class            0.289971    0.415368
# Human (Mean)  H_3x6            0.278908    0.405741
# Human (Mean)  H_5x8            0.295199    0.435055
# Human (Mean)  A                0.111765    0.19403
# Human (Mean)  S                0.120836    0.177313
#
# Comparing each of the embeddings against all  other methods:
#
#
# Metric 1    Metric 2        Kendall Tau    Spearman
# ----------  ------------  -------------  ----------
# H_3x6       Human (Mean)      0.278908     0.405741
# H_3x6       complex           0.399253     0.554779
# H_3x6       transe            0.426553     0.593709
# H_3x6       text              0.306283     0.446432
# H_3x6       class             0.292832     0.423766
# H_3x6       H_5x8             0.659819     0.838771
# H_3x6       A                 0.282353     0.376646
# H_3x6       S                 0.0471917    0.067061
#
#
# Metric 1    Metric 2        Kendall Tau    Spearman
# ----------  ------------  -------------  ----------
# H_5x8       Human (Mean)      0.295199     0.435055
# H_5x8       complex           0.458715     0.626852
# H_5x8       transe            0.481192     0.659268
# H_5x8       text              0.360842     0.519852
# H_5x8       class             0.326666     0.47633
# H_5x8       H_3x6             0.659819     0.838771
# H_5x8       A                 0.304987     0.418605
# H_5x8       S                 0.0711873    0.101839
#
#
# Metric 1    Metric 2        Kendall Tau    Spearman
# ----------  ------------  -------------  ----------
# A           Human (Mean)       0.111765    0.19403
# A           complex            0.460526    0.621901
# A           transe             0.434211    0.595041
# A           text               0.362637    0.6
# A           class              0.434211    0.549587
# A           H_3x6              0.282353    0.376646
# A           H_5x8              0.304987    0.418605
# A           S                  0.234605    0.36244
#
#
# Metric 1    Metric 2        Kendall Tau    Spearman
# ----------  ------------  -------------  ----------
# S           Human (Mean)      0.120836     0.177313
# S           complex           0.157587     0.233138
# S           transe            0.0889441    0.132387
# S           text              0.140569     0.206628
# S           class             0.132373     0.198451
# S           H_3x6             0.0471917    0.067061
# S           H_5x8             0.0711873    0.101839
# S           A                 0.234605     0.36244
